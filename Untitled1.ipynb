# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/Shareddrives/xm/OpenKE
# Out:
# /content/drive/Shareddrives/xm/OpenKE

# %%
# !python3 train_transd_FB15K237.py
# Out:
# Input Files Path : ./benchmarks/FB15K237/
# The toolkit is importing datasets.
# The total of relations is 237.
# The total of entities is 14541.
# The total of train triples is 272115.
# Input Files Path : ./benchmarks/FB15K237/
# The total of test triples is 20466.
# The total of valid triples is 17535.
# Finish initializing...
# Epoch 999 | loss: 0.920979: 100% 1000/1000 [1:26:22<00:00,  5.18s/it]
# 100% 20466/20466 [01:05<00:00, 311.15it/s]
# no type constraint results:
# metric:			 MRR 		 MR 		 hit@10 	 hit@3  	 hit@1
# l(raw):			 0.076904 	 614.737671 	 0.188263 	 0.072804 	 0.022672
# r(raw):			 0.230111 	 182.435165 	 0.421577 	 0.253249 	 0.134907
# averaged(raw):		 0.153508 	 398.586426 	 0.304920 	 0.163026 	 0.078789
#
# l(filter):		 0.187195 	 348.965057 	 0.365484 	 0.213183 	 0.097870
# r(filter):		 0.378614 	 154.275574 	 0.598163 	 0.440682 	 0.260921
# averaged(filter):	 0.282904 	 251.620316 	 0.481824 	 0.326932 	 0.179395
# 0.481824
# 0.48182350397109985

# %%
# !python3 train_transd_FB15K237.py
# Out:
# Input Files Path : ./benchmarks/FB15K237/
# The toolkit is importing datasets.
# The total of relations is 237.
# The total of entities is 14541.
# The total of train triples is 272115.
# Input Files Path : ./benchmarks/FB15K237/
# The total of test triples is 20466.
# The total of valid triples is 17535.
#
# a
# Finish initializing...
#   0% 0/1000 [00:00<?, ?it/s]> /content/drive/Shareddrives/xm/OpenKE/openke/module/model/TransD.py(124)forward()
# -> h = self._transfer(h, h_transfer, r_transfer)
# (Pdb)
# (Pdb) a
# self = TransD(
#   (ent_embeddings): Embedding(14541, 200)
#   (rel_embeddings): Embedding(237, 200)
#   (ent_transfer): Embedding(14541, 200)
#   (rel_transfer): Embedding(237, 200)
# )
# ...

# %%
dic = 
def dic_save(ls_or_dic, path):
    with open(path, 'w', encoding='utf-8') as f:
        f.write("%d\n"%(len(ls_or_dic)))
        for (idx, word) in enumerate(ls_or_dic):
            f.write(word+'\t'+str(idx)+'\n')

# %%
dic_save(ls, './test.txt')

# %%
# !python3 train_transr_GADM9.py
# Out:
# Input Files Path : ./benchmarks/GADM9/
# The toolkit is importing datasets.
# The total of relations is 9.
# The total of entities is 34715.
# The total of train triples is 398762.
# Input Files Path : ./benchmarks/GADM9/
# The total of test triples is 49845.
# The total of valid triples is 49845.
# TransR(
#   (ent_embeddings): Embedding(34715, 100)
#   (rel_embeddings): Embedding(9, 100)
#   (transfer_matrix): Embedding(9, 10000)
# )
# Finish initializing...
# Epoch 0 | loss: 33.832761: 100% 1/1 [00:04<00:00,  4.66s/it]
# lambda: 0.0001, gamma: 1.0, k: 100
# Finish initializing...
# Epoch 9 | loss: 15.704229: 100% 10/10 [12:05<00:00, 72.55s/it]
# 100% 49845/49845 [06:40<00:00, 124.39it/s]
# no type constraint results:
# metric:			 MRR 		 MR 		 hit@10 	 hit@3  	 hit@1
# l(raw):			 0.014036 	 13935.158203 	 0.016090 	 0.013702 	 0.012338
# r(raw):			 0.060178 	 3128.454590 	 0.163788 	 0.053205 	 0.014645
# averaged(raw):		 0.037107 	 8531.806641 	 0.089939 	 0.033454 	 0.013492
#
# ...

# %%
# !python3 train_transr_GADM9.py
# Out:
# Input Files Path : ./benchmarks/GADM9/
# The toolkit is importing datasets.
# The total of relations is 9.
# The total of entities is 34715.
# The total of train triples is 398762.
# Input Files Path : ./benchmarks/GADM9/
# The total of test triples is 49845.
# The total of valid triples is 49845.
# TransR(
#   (ent_embeddings): Embedding(34715, 100)
#   (rel_embeddings): Embedding(9, 100)
#   (transfer_matrix): Embedding(9, 10000)
# )
# Finish initializing...
# Epoch 0 | loss: 33.575419: 100% 1/1 [00:02<00:00,  2.69s/it]
# lambda: 0.1, gamma: 1.0, k: 100
# Finish initializing...
# Epoch 9 | loss: 2.114779: 100% 10/10 [04:53<00:00, 29.31s/it]
# 100% 49845/49845 [03:19<00:00, 249.65it/s]
# no type constraint results:
# metric:			 MRR 		 MR 		 hit@10 	 hit@3  	 hit@1
# l(raw):			 0.017724 	 11111.561523 	 0.025058 	 0.017013 	 0.013181
# r(raw):			 0.078001 	 2145.480957 	 0.219220 	 0.074511 	 0.016150
# averaged(raw):		 0.047862 	 6628.521484 	 0.122139 	 0.045762 	 0.014665
#
# ...

# %%
# !python3 train_transr_GADM9.py
# Out:
# Input Files Path : ./benchmarks/GADM9/
# The toolkit is importing datasets.
# The total of relations is 9.
# The total of entities is 34715.
# The total of train triples is 398762.
# Input Files Path : ./benchmarks/GADM9/
# The total of test triples is 49845.
# The total of valid triples is 49845.
# TransR(
#   (ent_embeddings): Embedding(34715, 100)
#   (rel_embeddings): Embedding(9, 100)
#   (transfer_matrix): Embedding(9, 10000)
# )
# Finish initializing...
# Epoch 0 | loss: 33.650600: 100% 1/1 [00:02<00:00,  2.47s/it]
# lambda: 1, gamma: 1.0, k: 100
# Finish initializing...
# Epoch 9 | loss: 0.280987: 100% 10/10 [04:55<00:00, 29.50s/it]
# 100% 49845/49845 [02:45<00:00, 302.07it/s]
# no type constraint results:
# metric:			 MRR 		 MR 		 hit@10 	 hit@3  	 hit@1
# l(raw):			 0.034566 	 5749.273438 	 0.076357 	 0.029752 	 0.013763
# r(raw):			 0.168438 	 763.731628 	 0.466346 	 0.214826 	 0.033444
# averaged(raw):		 0.101502 	 3256.502441 	 0.271351 	 0.122289 	 0.023603
#
# ...

# %%
# !python3 train_transe_GADM9.py
# Out:
# Input Files Path : ./benchmarks/GADM9/
# The toolkit is importing datasets.
# The total of relations is 9.
# The total of entities is 34715.
# The total of train triples is 398762.
# Input Files Path : ./benchmarks/GADM9/
# The total of test triples is 49845.
# The total of valid triples is 49845.
# NegativeSampling(
#   (model): TransE(
#     (ent_embeddings): Embedding(34715, 100)
#     (rel_embeddings): Embedding(9, 100)
#   )
#   (loss): MarginLoss()
# )
# lamda: 0.0001, gamma: 1.5, k: 100
# Finish initializing...
# Epoch 19 | loss: 115.073716:   2% 19/1000 [01:24<1:09:05,  4.23s/it]Epoch 19 has finished, saving...
# Epoch 39 | loss: 102.926861:   4% 39/1000 [02:49<1:07:52,  4.24s/it]Epoch 39 has finished, saving...
# Epoch 59 | loss: 94.319675:   6% 59/1000 [04:13<1:06:22,  4.23s/it]Epoch 59 has finished, saving...
# Epoch 79 | loss: 88.432647:   8% 79/1000 [05:38<1:04:39,  4.21s/it]Epoch 79 has finished, saving...
# ...

# %%
# !python3 train_transe_GADM9.py
# Out:
# Input Files Path : ./benchmarks/GADM9/
# The toolkit is importing datasets.
# The total of relations is 9.
# The total of entities is 34715.
# The total of train triples is 398762.
# Input Files Path : ./benchmarks/GADM9/
# The total of test triples is 49845.
# The total of valid triples is 49845.
# loading exist model sucessful...
# TransE(
#   (ent_embeddings): Embedding(34715, 100)
#   (rel_embeddings): Embedding(9, 100)
# )
# lamda: 0.0001, gamma: 1.5, k: 100
# Finish initializing...
# Epoch 19 | loss: 35.776886:   4% 19/500 [01:25<34:15,  4.27s/it]Epoch 19 has finished, saving...
# Epoch 39 | loss: 35.674696:   8% 39/500 [02:51<32:55,  4.28s/it]Epoch 39 has finished, saving...
# Epoch 59 | loss: 35.052663:  12% 59/500 [04:16<31:28,  4.28s/it]Epoch 59 has finished, saving...
# Epoch 79 | loss: 34.730452:  16% 79/500 [05:42<29:56,  4.27s/it]Epoch 79 has finished, saving...
# Epoch 99 | loss: 34.396659:  20% 99/500 [07:07<28:26,  4.26s/it]Epoch 99 has finished, saving...
# ...
