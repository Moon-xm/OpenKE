# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/Shareddrives/xm/OpenKE
# Out:
# /content/drive/Shareddrives/xm/OpenKE

# %%
# !python3 train_transe_FB15K237.py
# Out:
# Input Files Path : ./benchmarks/FB15K237/
# The toolkit is importing datasets.
# The total of relations is 237.
# The total of entities is 14541.
# The total of train triples is 272115.
# Input Files Path : ./benchmarks/FB15K237/
# The total of test triples is 20466.
# The total of valid triples is 17535.
# Finish initializing...
# Epoch 999 | loss: 2.377852: 100% 1000/1000 [45:25<00:00,  2.73s/it]
# 100% 20466/20466 [00:37<00:00, 550.09it/s]
# no type constraint results:
# metric:			 MRR 		 MR 		 hit@10 	 hit@3  	 hit@1
# l(raw):			 0.087633 	 568.316162 	 0.205609 	 0.086241 	 0.031565
# r(raw):			 0.250981 	 166.653625 	 0.440194 	 0.271328 	 0.159093
# averaged(raw):		 0.169307 	 367.484894 	 0.322901 	 0.178784 	 0.095329
#
# l(filter):		 0.190622 	 314.872375 	 0.362455 	 0.215382 	 0.105394
# r(filter):		 0.387724 	 140.605255 	 0.596941 	 0.440340 	 0.279488
# averaged(filter):	 0.289173 	 227.738815 	 0.479698 	 0.327861 	 0.192441
# 0.479698
# 0.4796980619430542

# %%
# !python3 train_transe_FB15K.py
# Out:
# Input Files Path : ./benchmarks/FB15K/
# The toolkit is importing datasets.
# The total of relations is 1345.
# The total of entities is 14951.
# The total of train triples is 483142.
# Input Files Path : ./benchmarks/FB15K/
# The total of test triples is 59071.
# The total of valid triples is 50000.
# Finish initializing...
# Epoch 4 | loss: 12.332316:   0% 5/1000 [00:17<58:17,  3.51s/it]Traceback (most recent call last):
#   File "train_transe_FB15K.py", line 41, in <module>
#     trainer.run()
#   File "/content/drive/Shareddrives/xm/OpenKE/openke/config/Trainer.py", line 93, in run
#     loss = self.train_one_step(data)
#   File "/content/drive/Shareddrives/xm/OpenKE/openke/config/Trainer.py", line 52, in train_one_step
#     loss.backward()
#   File "/usr/local/lib/python3.7/dist-packages/torch/tensor.py", line 245, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
# ...

# %%
# !python3 train_transr_FB15K237.py
# Out:
# Input Files Path : ./benchmarks/FB15K237/
# The toolkit is importing datasets.
# The total of relations is 237.
# The total of entities is 14541.
# The total of train triples is 272115.
# Input Files Path : ./benchmarks/FB15K237/
# The total of test triples is 20466.
# The total of valid triples is 17535.
# Finish initializing...
# Epoch 0 | loss: 199.138807: 100% 1/1 [00:02<00:00,  2.06s/it]
# Finish initializing...
#   0% 0/1000 [00:00<?, ?it/s]Traceback (most recent call last):
#   File "train_transr_FB15K237.py", line 61, in <module>
#     trainer.run()
#   File "/content/drive/Shareddrives/xm/OpenKE/openke/config/Trainer.py", line 93, in run
#     loss = self.train_one_step(data)
#   File "/content/drive/Shareddrives/xm/OpenKE/openke/config/Trainer.py", line 52, in train_one_step
#     loss.backward()
#   File "/usr/local/lib/python3.7/dist-packages/torch/tensor.py", line 245, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
# ...

# %%
# !python3 train_transd_FB15K237.py
# Out:
# Input Files Path : ./benchmarks/FB15K237/
# The toolkit is importing datasets.
# The total of relations is 237.
# The total of entities is 14541.
# The total of train triples is 272115.
# Input Files Path : ./benchmarks/FB15K237/
# The total of test triples is 20466.
# The total of valid triples is 17535.
# Finish initializing...
# Epoch 999 | loss: 0.920979: 100% 1000/1000 [1:26:22<00:00,  5.18s/it]
# 100% 20466/20466 [01:05<00:00, 311.15it/s]
# no type constraint results:
# metric:			 MRR 		 MR 		 hit@10 	 hit@3  	 hit@1
# l(raw):			 0.076904 	 614.737671 	 0.188263 	 0.072804 	 0.022672
# r(raw):			 0.230111 	 182.435165 	 0.421577 	 0.253249 	 0.134907
# averaged(raw):		 0.153508 	 398.586426 	 0.304920 	 0.163026 	 0.078789
#
# l(filter):		 0.187195 	 348.965057 	 0.365484 	 0.213183 	 0.097870
# r(filter):		 0.378614 	 154.275574 	 0.598163 	 0.440682 	 0.260921
# averaged(filter):	 0.282904 	 251.620316 	 0.481824 	 0.326932 	 0.179395
# 0.481824
# 0.48182350397109985

# %%
# !pip install ipdb

# %%
# !python3 train_transe_FB15K237.py
# Out:
# > /content/drive/Shareddrives/xm/OpenKE/openke/data/TrainDataLoader.py(42)__init__()
#      41                 import ipdb; ipdb.set_trace()
# ---> 42                 base_file = os.path.abspath(os.path.join(os.path.dirname(__file__), "../release/Base.so"))
#      43                 self.lib = ctypes.cdll.LoadLibrary(base_file)
#
# ipdb> WARNING: your terminal doesn't support cursor position requests (CPR).
# ipdb> ipdb> n
# > /content/drive/Shareddrives/xm/OpenKE/openke/data/TrainDataLoader.py(43)__init__()
#      42                 base_file = os.path.abspath(os.path.join(os.path.dirname(__file__), "../release/Base.so"))
# ---> 43                 self.lib = ctypes.cdll.LoadLibrary(base_file)
#      44                 """argtypes"""
#
# ipdb> ipdb> b 76
# Breakpoint 1 at /content/drive/Shareddrives/xm/OpenKE/openke/data/TrainDataLoader.py:76
# ipdb> ipdb> c
# > /content/drive/Shareddrives/xm/OpenKE/openke/data/TrainDataLoader.py(76)__init__()
# ...

# %%
cp /content/drive/Shareddrives/xm/OpenKE/benchmarks/FB15K/n-n.py /content/drive/Shareddrives/xm/OpenKE/benchmarks/GADM9

# %%
cd /content/drive/Shareddrives/xm/OpenKE/benchmarks/GADM9
# Out:
# /content/drive/Shareddrives/xm/OpenKE/benchmarks/GADM9

# %%
# !python3 n-n.py

# %%
cd /content/drive/Shareddrives/xm/OpenKE/
# Out:
# /content/drive/Shareddrives/xm/OpenKE

# %% [markdown]
# ###  lambda: 0.0001, gamma: 1.5, k: 100(实验发现学习率太小了，loss下降慢）

# %% [markdown]
# 10 epoch  论文参数

# %%
# !python3 train_transe_GADM9.py
# Out:
# Input Files Path : ./benchmarks/GADM9/
# The toolkit is importing datasets.
# The total of relations is 9.
# The total of entities is 34715.
# The total of train triples is 398762.
# Input Files Path : ./benchmarks/GADM9/
# The total of test triples is 49845.
# The total of valid triples is 49845.
# TransE(
#   (ent_embeddings): Embedding(34715, 100)
#   (rel_embeddings): Embedding(9, 100)
# )
# lambda: 0.0001, gamma: 1.5, k: 100
# Finish initializing...
# Epoch 9 | loss: 126.464522: 100% 10/10 [00:17<00:00,  1.80s/it]
# 100% 49845/49845 [03:52<00:00, 214.48it/s]
# no type constraint results:
# metric:			 MRR 		 MR 		 hit@10 	 hit@3  	 hit@1
# l(raw):			 0.014071 	 17171.974609 	 0.014023 	 0.013843 	 0.013783
# r(raw):			 0.018019 	 13773.267578 	 0.024576 	 0.017735 	 0.013783
# averaged(raw):		 0.016045 	 15472.621094 	 0.019300 	 0.015789 	 0.013783
#
# l(filter):		 0.014086 	 16819.302734 	 0.014064 	 0.013843 	 0.013783
# ...

# %% [markdown]
# 100 epoch  论文参数

# %%
# !python3 train_transe_GADM9.py
# Out:
# Input Files Path : ./benchmarks/GADM9/
# The toolkit is importing datasets.
# The total of relations is 9.
# The total of entities is 34715.
# The total of train triples is 398762.
# Input Files Path : ./benchmarks/GADM9/
# The total of test triples is 49845.
# The total of valid triples is 49845.
# TransE(
#   (ent_embeddings): Embedding(34715, 100)
#   (rel_embeddings): Embedding(9, 100)
# )
# lambda: 0.0001, gamma: Parameter containing:
# tensor([1.5000]), k: 100
# Finish initializing...
# Epoch 99 | loss: 83.133645: 100% 100/100 [02:58<00:00,  1.79s/it]
# 100% 49845/49845 [03:42<00:00, 223.96it/s]
# no type constraint results:
# metric:			 MRR 		 MR 		 hit@10 	 hit@3  	 hit@1
# l(raw):			 0.014097 	 16938.173828 	 0.014104 	 0.013883 	 0.013783
# r(raw):			 0.045853 	 8899.527344 	 0.126552 	 0.045300 	 0.013843
# averaged(raw):		 0.029975 	 12918.850586 	 0.070328 	 0.029592 	 0.013813
#
# l(filter):		 0.014129 	 16590.531250 	 0.014104 	 0.013903 	 0.013823
# ...

# %% [markdown]
# 1000 epoch  论文参数（loss下降太慢，增大学习率进行计算）

# %%
# !python3 train_transe_GADM9.py
# Out:
# Input Files Path : ./benchmarks/GADM9/
# The toolkit is importing datasets.
# The total of relations is 9.
# The total of entities is 34715.
# The total of train triples is 398762.
# Input Files Path : ./benchmarks/GADM9/
# The total of test triples is 49845.
# The total of valid triples is 49845.
# TransE(
#   (ent_embeddings): Embedding(34715, 100)
#   (rel_embeddings): Embedding(9, 100)
# )
# lambda: 0.0001, gamma: 1.5, k: 100
# Finish initializing...
# Epoch 643 | loss: 46.047550:  64% 644/1000 [19:22<10:54,  1.84s/it]

# %% [markdown]
# 将学习率设置为1

# %%
# !python3 train_transe_GADM9.py
# Out:
# Input Files Path : ./benchmarks/GADM9/
# The toolkit is importing datasets.
# The total of relations is 9.
# The total of entities is 34715.
# The total of train triples is 398762.
# Input Files Path : ./benchmarks/GADM9/
# The total of test triples is 49845.
# The total of valid triples is 49845.
# TransE(
#   (ent_embeddings): Embedding(34715, 100)
#   (rel_embeddings): Embedding(9, 100)
# )
# lambda: 1, gamma: 1.5, k: 100
# Finish initializing...
# Epoch 99 | loss: 0.048104: 100% 100/100 [03:51<00:00,  2.32s/it]
# 100% 49845/49845 [02:00<00:00, 413.26it/s]
# no type constraint results:
# metric:			 MRR 		 MR 		 hit@10 	 hit@3  	 hit@1
# l(raw):			 0.052872 	 2429.241943 	 0.134918 	 0.037115 	 0.014104
# r(raw):			 0.297506 	 114.022011 	 0.752252 	 0.471482 	 0.048530
# averaged(raw):		 0.175189 	 1271.631958 	 0.443585 	 0.254298 	 0.031317
#
# l(filter):		 0.184404 	 2053.011719 	 0.345712 	 0.206099 	 0.106109
# ...

# %%
# !python3 train_transe_GeoDBpedia21.py
# Out:
# Input Files Path : ./benchmarks/GeoDBpedia21/
# The toolkit is importing datasets.
# The total of relations is 21.
# The total of entities is 84988.
# The total of train triples is 79338.
# Input Files Path : ./benchmarks/GeoDBpedia21/
# The total of test triples is 9917.
# The total of valid triples is 9917.
# TransE(
#   (ent_embeddings): Embedding(84988, 100)
#   (rel_embeddings): Embedding(21, 100)
# )
# lambda: 0.1, gamma: 10.0, k: 100
# Finish initializing...
# Epoch 99 | loss: 13.838956: 100% 100/100 [01:11<00:00,  1.39it/s]
# 100% 9917/9917 [01:02<00:00, 159.16it/s]
# no type constraint results:
# metric:			 MRR 		 MR 		 hit@10 	 hit@3  	 hit@1
# l(raw):			 0.055536 	 23104.300781 	 0.101946 	 0.064536 	 0.031058
# r(raw):			 0.191072 	 7099.735840 	 0.324796 	 0.235152 	 0.111223
# averaged(raw):		 0.123304 	 15102.018555 	 0.213371 	 0.149844 	 0.071140
#
# l(filter):		 0.133508 	 22872.710938 	 0.183624 	 0.144701 	 0.105576
# ...

# %%
# !python3 train_transe_GeoDBpedia21.py
# Out:
# Input Files Path : ./benchmarks/GeoDBpedia21/
# The toolkit is importing datasets.
# The total of relations is 21.
# The total of entities is 84988.
# The total of train triples is 79338.
# Input Files Path : ./benchmarks/GeoDBpedia21/
# The total of test triples is 9917.
# The total of valid triples is 9917.
# TransE(
#   (ent_embeddings): Embedding(84988, 100)
#   (rel_embeddings): Embedding(21, 100)
# )
# lambda: 0.1, gamma: 10.0, k: 100
# Finish initializing...
# Epoch 999 | loss: 5.873224: 100% 1000/1000 [12:06<00:00,  1.38it/s]
# 100% 9917/9917 [01:01<00:00, 162.11it/s]
# no type constraint results:
# metric:			 MRR 		 MR 		 hit@10 	 hit@3  	 hit@1
# l(raw):			 0.056533 	 20797.900391 	 0.103660 	 0.064636 	 0.032167
# r(raw):			 0.194024 	 8913.244141 	 0.318846 	 0.237269 	 0.115761
# averaged(raw):		 0.125279 	 14855.572266 	 0.211253 	 0.150953 	 0.073964
#
# l(filter):		 0.132913 	 20562.671875 	 0.190279 	 0.144600 	 0.102148
# ...

# %%
# !python3 train_transe_GeoDBpedia21.py
# Out:
# Input Files Path : ./benchmarks/GeoDBpedia21/
# The toolkit is importing datasets.
# The total of relations is 21.
# The total of entities is 84988.
# The total of train triples is 79338.
# Input Files Path : ./benchmarks/GeoDBpedia21/
# The total of test triples is 9917.
# The total of valid triples is 9917.
# TransE(
#   (ent_embeddings): Embedding(84988, 100)
#   (rel_embeddings): Embedding(21, 100)
# )
# lamda: 0.1, gamma: 10.0, k: 100
# Finish initializing...
# Epoch 6777 | loss: 4.173731:  68% 6778/10000 [1:20:50<38:24,  1.40it/s]
